# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushJkumar/Image-iCrawler/blob/main/Image_iCrawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install glob2

# %%
# !pip install icrawler

# %%
from icrawler.builtin import  (BingImageCrawler,GoogleImageCrawler)
import logging

# %%
# downloading images of the car
# pass no. of maximum images in max_num arguement
directory_bing_car = '/content/drive/MyDrive/Image icawler/Bollywood Actors'
search_filters_bing = dict()
bing_crawler = BingImageCrawler(downloader_threads=4,storage={'root_dir': directory_bing_car},log_level=logging.INFO)
bing_crawler.crawl(keyword='Bollywood Actors', filters=search_filters_bing, max_num=100)
# Out:
# 2022-03-04 06:50:37,146 - INFO - icrawler.crawler - start crawling...
# 2022-03-04 06:50:37,149 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-03-04 06:50:37,152 - INFO - feeder - thread feeder-001 exit
# 2022-03-04 06:50:37,155 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-03-04 06:50:37,166 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2022-03-04 06:50:37,505 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Bollywood Actors&first=0
# 2022-03-04 06:50:37,801 - INFO - downloader - image #1	https://2.bp.blogspot.com/-UJf-AHzQu0k/WaeMe7RB6wI/AAAAAAAALbg/W6WIG2uoYsclUfstoxk77INjZdwZ5M-6gCLcBGAs/s1600/10-Shahid-Kapoor.jpg
# 2022-03-04 06:50:37,836 - INFO - downloader - image #2	https://www.findhealthtips.com/wp-content/uploads/2019/01/1082.jpg
# 2022-03-04 06:50:37,877 - INFO - downloader - image #3	https://findhealthtips.com/wp-content/uploads/2019/01/1081.jpg
# ...

# %%
# downloading images of the car
# pass no. of maximum images in max_num arguement
directory_bing_car = '/content/drive/MyDrive/Image icawler/Hollywood Actors'
search_filters_bing = dict()
bing_crawler = BingImageCrawler(downloader_threads=4,storage={'root_dir': directory_bing_car},log_level=logging.INFO)
bing_crawler.crawl(keyword='Hollywood Actors', filters=search_filters_bing, max_num=210)
# Out:
# 2022-03-04 06:52:47,864 - INFO - icrawler.crawler - start crawling...
# 2022-03-04 06:52:47,866 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-03-04 06:52:47,870 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-03-04 06:52:47,874 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2022-03-04 06:52:48,261 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Hollywood Actors&first=0
# 2022-03-04 06:52:48,413 - INFO - downloader - image #1	http://wallpapercave.com/wp/gyDqsus.jpg
# 2022-03-04 06:52:48,739 - INFO - downloader - image #2	https://wallpapercave.com/wp/wc1792582.jpg
# 2022-03-04 06:52:48,750 - INFO - downloader - image #3	https://www.topinspired.com/wp-content/uploads/2014/12/Nicholas-Hoult.jpg
# 2022-03-04 06:52:49,098 - INFO - downloader - image #4	https://www.topinspired.com/wp-content/uploads/2014/12/ryan-gosling.jpg
# ...

# %%
# downloading images of the car
# pass no. of maximum images in max_num arguement
directory_bing_car = '/content/drive/MyDrive/Image icawler/Historical Places of the world'
search_filters_bing = dict()
bing_crawler = BingImageCrawler(downloader_threads=4,storage={'root_dir': directory_bing_car},log_level=logging.INFO)
bing_crawler.crawl(keyword='Historical Places of the world', filters=search_filters_bing, max_num=170)
# Out:
# 2022-03-04 06:59:53,560 - INFO - icrawler.crawler - start crawling...
# 2022-03-04 06:59:53,568 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-03-04 06:59:53,572 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-03-04 06:59:53,576 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2022-03-04 06:59:53,999 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Historical Places of the world&first=0
# 2022-03-04 06:59:54,373 - INFO - downloader - image #1	https://globalcastaway.com/wp-content/uploads/2019/08/acropolis.jpg
# 2022-03-04 06:59:54,442 - INFO - downloader - image #2	http://www.travelhoundsusa.com/wp-content/uploads/2018/04/The-Historical-Traveller-Guide-to-the-Most-Beautiful-Places-in-the-World-Petra-in-Jordan.jpg
# 2022-03-04 06:59:54,599 - INFO - downloader - image #3	https://image.slidesharecdn.com/englishpresentation-140304033734-phpapp01/95/top-5-historical-places-of-the-world-4-638.jpg
# ...

# %%
# downloading images of the car
# pass no. of maximum images in max_num arguement
directory_bing_car = '/content/drive/MyDrive/Image icawler/Group Photo'
search_filters_bing = dict()
bing_crawler = BingImageCrawler(downloader_threads=4,storage={'root_dir': directory_bing_car},log_level=logging.INFO)
bing_crawler.crawl(keyword='Group photos with friends', filters=search_filters_bing, max_num=170)
# Out:
# 2022-03-04 07:03:38,531 - INFO - icrawler.crawler - start crawling...
# 2022-03-04 07:03:38,533 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2022-03-04 07:03:38,536 - INFO - icrawler.crawler - starting 1 parser threads...
# 2022-03-04 07:03:38,540 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2022-03-04 07:03:39,029 - INFO - parser - parsing result page https://www.bing.com/images/async?q=Group photos with friends&first=0
# 2022-03-04 07:03:39,353 - INFO - downloader - image #1	https://i.pinimg.com/originals/a1/e0/28/a1e0288fe62e9f129851b3cb7b02eaa5.jpg
# 2022-03-04 07:03:39,440 - INFO - downloader - image #2	https://www.sierravistaaz.gov/wp-content/uploads/2016/12/Teen-Leadership-group-friendsn-website-1200x1200.jpg
# 2022-03-04 07:03:39,491 - INFO - downloader - image #3	http://allisonragsdalephotography.com/wp-content/uploads/2013/07/allisonragsdalephotography-7137.jpg
# ...
